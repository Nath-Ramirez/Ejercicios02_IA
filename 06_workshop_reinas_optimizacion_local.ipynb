# %% [markdown]
# # Optimización local: el problema de las 4 reinas
#
# En este ejercicio modelaremos el problema de las **4 reinas** como un problema de optimización y construiremos tres algoritmos:
#
# 1. **Hill Climbing**
# 2. **Hill Climbing con Random Restart**
# 3. **Simulated Annealing**
#
# La mayor parte de las funciones están incompletas. Deben implementarse durante la clase.
#
# ---
#
# ## Objetivo
#
# Ubicar cuatro reinas en un tablero $4 \times 4$ de forma que ninguna pareja se ataque.
#
# Una reina ataca a otra si ambas están:
#
# - en la misma fila;
# - en la misma columna;
# - en la misma diagonal.

# %% [markdown]
# ## 1. Formulación como problema de optimización
#
# Representaremos un estado mediante un vector:
#
# $$
# x = [x_0, x_1, x_2, x_3]
# $$
#
# donde $x_i$ indica la **fila** de la reina ubicada en la columna $i$.
#
# Por ejemplo:
#
# $$
# x = [1, 3, 0, 2]
# $$
#
# representa las posiciones:
#
# $$
# (1,0), (3,1), (0,2), (2,3)
# $$
#
# Como cada columna contiene exactamente una reina, no pueden existir conflictos por columna.
#
# ### Espacio de búsqueda
#
# Cada una de las cuatro reinas puede estar en cualquiera de las cuatro filas:
#
# $$
# |\mathcal{X}| = 4^4 = 256
# $$
#
# ### Función de costo
#
# Definiremos:
#
# $$
# C(x) = \text{número de parejas de reinas que se atacan}
# $$
#
# El objetivo es resolver:
#
# $$
# \min_{x \in \mathcal{X}} C(x)
# $$
#
# Una solución válida satisface:
#
# $$
# C(x)=0
# $$

# %%
import math
import random
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

cmap = ListedColormap(["#F0D9B5", "#B58863"])



N = 4
SEED = 42
random.seed(SEED)

# %% [markdown]
# ## 2. Visualización de un estado

# %%
def plot_board(state, title=None):
    """Visualiza un estado del problema de las N reinas."""
    n = len(state)
    board = [[(row + col) % 2 for col in range(n)] for row in range(n)]

    plt.figure(figsize=(4, 4))
    plt.imshow(board, cmap="Greys", vmin=0, vmax=1)

    for col, row in enumerate(state):
        plt.text(col, row, "♛", ha="center", va="center", fontsize=32)

    plt.xticks(range(n))
    plt.yticks(range(n))
    plt.xlabel("Columna")
    plt.ylabel("Fila")
    plt.grid(False)
    if title:
        plt.title(title)

    plt.imshow(board, cmap=cmap)


example_state = [1, 3, 0, 2]
plot_board(example_state, title=f"Estado {example_state}")

# %% [markdown]
# ## Actividad 1. Detectar conflictos
#
# Dos reinas ubicadas en $(r_i,c_i)$ y $(r_j,c_j)$ se atacan si:
#
# $$
# r_i = r_j
# $$
#
# o si están en la misma diagonal:
#
# $$
# |r_i-r_j| = |c_i-c_j|
# $$
#
# Complete la función `attacking`.

# %%
def attacking(row_i, col_i, row_j, col_j):
    """Retorna True si dos reinas se atacan."""

    # Se asume que existe una reina por columna
    if row_i == row_j or (abs(row_i - row_j) == abs(col_i - col_j)):
      return True
    else:
      return False

# %%
# Pruebas de la actividad 1
assert attacking(0, 0, 0, 3) is True       # misma fila
assert attacking(0, 0, 3, 3) is True       # misma diagonal
assert attacking(0, 0, 1, 3) is False      # no se atacan

print("Pruebas superadas.")
# Out:
# Pruebas superadas.

# %% [markdown]
# ## Actividad 2. Función de costo
#
# Implemente una función que cuente cuántas parejas de reinas se atacan.
#
# Para cuatro reinas existen:
#
# $$
# \binom{4}{2}=6
# $$
#
# parejas posibles.

# %%
def cost(state):
    """Cuenta el número de parejas de reinas que se atacan."""
    collide = 0
    for col_i, row_i in enumerate(state):
      for col_j in range(col_i + 1, len(state)):
        row_j = state[col_j]

        if (attacking(row_i, col_i, row_j, col_j)):
          collide += 1

    return collide

# %%
# Pruebas de la actividad 2
assert cost([0, 0, 0, 0]) == 6
assert cost([0, 1, 2, 3]) == 6
assert cost([1, 3, 0, 2]) == 0

print("Pruebas superadas.")
# Out:
# Pruebas superadas.

# %% [markdown]
# ## 3. Vecindario
#
# Un vecino se obtiene moviendo **una sola reina** a otra fila de su misma columna.
#
# Para cada una de las $N$ columnas hay $N-1$ movimientos posibles:
#
# $$
# |N(x)| = N(N-1)
# $$
#
# Para $N=4$:
#
# $$
# |N(x)|=4(3)=12
# $$

# %% [markdown]
# ## Actividad 3. Generar los vecinos
#
# Implemente `neighbors(state)`.
#
# La función debe retornar todos los estados que difieren del original en la fila de exactamente una reina.

# %%
def neighbors(state):
    """Genera todos los estados vecinos moviendo una reina."""

    neighbors = []

    for col_i, row_i in enumerate(state):
      for row in range(len(state)):
        if row == row_i: continue

        new_neighbor = state[:]
        new_neighbor[col_i] = row

        neighbors.append(new_neighbor)
    return neighbors

# %%
# Pruebas de la actividad 3
test_state = [0, 1, 2, 3]
test_neighbors = neighbors(test_state)

assert len(test_neighbors) == 12
assert test_state not in test_neighbors
assert len({tuple(s) for s in test_neighbors}) == 12

print("Pruebas superadas.")
# Out:
# Pruebas superadas.

# %% [markdown]
# ## Actividad 4. Mejor vecino
#
# Implemente una función que encuentre el menor costo entre todos los vecinos.
#
# Cuando existan varios vecinos con el mismo costo mínimo, seleccione uno aleatoriamente.

# %%
def best_neighbor(state):
    """Retorna un vecino de costo mínimo y su costo."""

    current_neighbors = neighbors(state)
    next_best_neighbor = None
    next_best_cost = None

    for current_state in current_neighbors:
      current_cost = cost(current_state)

      if next_best_cost is None or next_best_cost > current_cost:
        next_best_cost = current_cost
        next_best_neighbor = current_state

    return next_best_neighbor, next_best_cost

# %%
# Prueba básica
state = [0, 0, 0, 0]
next_state, next_cost = best_neighbor(state)

assert next_state in neighbors(state)
assert next_cost == cost(next_state)
assert next_cost == min(cost(s) for s in neighbors(state))

print("Pruebas superadas.")
# Out:
# Pruebas superadas.

# %% [markdown]
# ## 4. Hill Climbing
#
# Hill Climbing comienza en un estado inicial y se mueve repetidamente hacia un vecino con menor costo.
#
# $$
# x_{t+1} = \arg\min_{y \in N(x_t)} C(y)
# $$
#
# El algoritmo termina cuando:
#
# - encuentra una solución con costo cero; o
# - ningún vecino mejora el estado actual.
#
# Este segundo caso puede corresponder a un **mínimo local** o a una **meseta**.

# %% [markdown]
# ## Actividad 5. Implementar Hill Climbing

# %%
def hill_climbing(initial_state, max_steps=100):
    """
    Ejecuta Hill Climbing.

    Retorna:
        final_state: estado alcanzado
        history: lista con los estados visitados
    """
    current_state = initial_state
    history = []

    for _ in range(max_steps):
      history.append(current_state)

      next_state, next_cost = best_neighbor(current_state)
      current_cost = cost(current_state)

      if next_cost >= current_cost:
         break

      current_state = next_state

    return current_state, history

# %%
initial_state = [0, 0, 0, 0]
final_state, history = hill_climbing(initial_state)

print("Estado inicial:", initial_state)
print("Estado final:", final_state)
print("Costo final:", cost(final_state))
print("Número de movimientos:", len(history) - 1)

plot_board(initial_state, "Estado inicial")
plot_board(final_state, f"Estado final — costo {cost(final_state)}")
# Out:
# Estado inicial: [0, 0, 0, 0]
# Estado final: [1, 3, 0, 2]
# Costo final: 0
# Número de movimientos: 3

# %% [markdown]
# ## Actividad 6. Analizar una ejecución
#
# Grafique el costo de los estados visitados por Hill Climbing.

# %%
def plot_cost_history(history, title="Evolución del costo"):
    costs = [cost(state) for state in history]

    plt.figure(figsize=(7, 4))
    plt.plot(range(len(costs)), costs, marker="o")
    plt.xlabel("Iteración")
    plt.ylabel("Costo")
    plt.title(title)
    plt.xticks(range(len(costs)))
    plt.show()


plot_cost_history(history)

# %% [markdown]
# ## 5. Hill Climbing con Random Restart
#
# Hill Climbing puede quedar atrapado en mínimos locales.
#
# Random Restart ejecuta Hill Climbing desde diferentes estados iniciales:
#
# $$
# x_0^{(1)}, x_0^{(2)}, \ldots, x_0^{(R)}
# $$
#
# El algoritmo termina cuando encuentra una solución o cuando agota el número máximo de reinicios.

# %% [markdown]
# ## Actividad 7. Implementar Random Restart

# %%
def random_state(n=N):
    """Genera un estado aleatorio."""
    return [random.randrange(n) for _ in range(n)]


def random_restart_hill_climbing(max_restarts=50, max_steps=100):
    """
    Ejecuta Hill Climbing desde varios estados iniciales.

    Retorna:
        best_state: mejor estado encontrado
        best_history: trayectoria de la mejor ejecución
        restarts_used: número de reinicios realizados
    """
    runs = []
    best_history = []
    best_state = None
    best_initial_state = None

    for restart in range(max_restarts):
      state = random_state()

      solution, history = hill_climbing(state, max_steps)
      runs.append((solution, history))

      if best_state is None or cost(solution) < cost(best_state):
        best_state = solution
        best_history = history
        best_initial_state = state

      if cost(solution) == 0: break

    #print(best_initial_state)
    return best_state, best_history, len(runs)

# %%
best_state, best_history, restarts = random_restart_hill_climbing()

print("Mejor estado:", best_state)
print("Costo:", cost(best_state))
print("Reinicios utilizados:", restarts)

plot_board(best_state, f"Random Restart — costo {cost(best_state)}")
plot_cost_history(best_history, "Mejor ejecución de Random Restart")
# Out:
# Mejor estado: [2, 0, 3, 1]
# Costo: 0
# Reinicios utilizados: 3

# %% [markdown]
# ## 6. Simulated Annealing
#
# Simulated Annealing permite aceptar temporalmente movimientos que empeoran la solución.
#
# Si un vecino tiene costo menor o igual, se acepta.
#
# Si empeora el costo en una cantidad:
#
# $$
# \Delta C = C(x') - C(x) > 0
# $$
#
# se acepta con probabilidad:
#
# $$
# P(\text{aceptar}) = e^{-\Delta C/T}
# $$
#
# donde $T$ es la temperatura.
#
# Usaremos un enfriamiento geométrico:
#
# $$
# T_{t+1} = \alpha T_t
# $$
#
# con $0 < \alpha < 1$.

# %% [markdown]
# ## Actividad 8. Probabilidad de aceptación

# %%
def acceptance_probability(current_cost, candidate_cost, temperature):
    """Calcula la probabilidad de aceptar un estado candidato."""

    delta_c = candidate_cost - current_cost
    return 1 if delta_c < 0 else math.exp(-delta_c / temperature)

# %%
assert acceptance_probability(3, 2, 1.0) == 1.0
assert acceptance_probability(3, 3, 1.0) == 1.0

p = acceptance_probability(2, 3, 1.0)
assert math.isclose(p, math.exp(-1), rel_tol=1e-9)

print("Pruebas superadas.")
# Out:
# Pruebas superadas.

# %% [markdown]
# ## Actividad 9. Implementar Simulated Annealing
#
# En cada iteración:
#
# 1. seleccione un vecino aleatorio;
# 2. calcule el cambio de costo;
# 3. acepte siempre las mejoras;
# 4. acepte algunos movimientos peores según la temperatura;
# 5. reduzca la temperatura.

# %%
def simulated_annealing(
    initial_state,
    initial_temperature=10.0,
    cooling_rate=0.95,
    min_temperature=1e-3,
    max_steps=1000,
):
    """
    Ejecuta Simulated Annealing.

    Retorna:
        best_state: mejor estado encontrado
        history: estados aceptados durante la búsqueda
        temperatures: temperatura asociada a cada estado
    """
    best_state = initial_state # Crea una copia del initial state
    best_cost = None
    history = []
    temperatures = []

    current_temperature = initial_temperature
    final_step = 0

    for _ in range(max_steps):
      current_neighbor = random.choice(neighbors(initial_state))
      current_best_state, current_best_cost = best_neighbor(current_neighbor)

      probability = acceptance_probability(cost(best_state), current_best_cost, current_temperature)
      accepted = random.random() <= probability # Si probability es 1, esto siempre sera verdadero

      if accepted:
        best_state, best_cost = current_best_state, current_best_cost
        history.append(best_state)
        final_step = _

      temperatures.append(current_temperature)

      current_temperature *= cooling_rate
    print("final ", final_step)
    return best_state, history, temperatures

# %%
initial_state = random_state()
sa_state, sa_history, temperatures = simulated_annealing(initial_state)

print("Estado inicial:", initial_state)
print("Mejor estado:", sa_state)
print("Costo final:", cost(sa_state))
print("Estados aceptados:", len(sa_history))

plot_board(initial_state, "Estado inicial")
plot_board(sa_state, f"Simulated Annealing — costo {cost(sa_state)}")
plot_cost_history(sa_history, "Evolución del costo en Simulated Annealing")
# Out:
# final  992
# Estado inicial: [3, 0, 1, 0]
# Mejor estado: [2, 0, 3, 0]
# Costo final: 1
# Estados aceptados: 411

# %% [markdown]
# ## Actividad 10. Comparación experimental
#
# Ejecute cada algoritmo varias veces y registre su tasa de éxito.
#
# Una ejecución es exitosa cuando encuentra un estado con costo cero.

# %%
def compare_algorithms(trials=100):
    results = {
        "Hill Climbing": 0,
        "Random Restart": 0,
        "Simulated Annealing": 0,
    }

    for _ in range(trials):
        initial_state = random_state()

        hc_state, _ = hill_climbing(initial_state)
        if cost(hc_state) == 0:
            results["Hill Climbing"] += 1

        rr_state, _, _ = random_restart_hill_climbing(max_restarts=20)
        if cost(rr_state) == 0:
            results["Random Restart"] += 1

        sa_state, _, _ = simulated_annealing(initial_state)
        if cost(sa_state) == 0:
            results["Simulated Annealing"] += 1

    return results


# Descomente cuando haya terminado todas las implementaciones.
results = compare_algorithms(trials=100)
for algorithm, successes in results.items():
    print(f"{algorithm:20s}: {successes}/100")
# Out:
# [2, 0, 1, 0]
# final  996
# [0, 3, 3, 3]
# [0, 0, 0, 0]
# final  999
# [3, 0, 3, 1]
# final  992
# [2, 0, 1, 1]
# final  999
# [0, 1, 0, 1]
# [3, 0, 3, 0]
# final  993
# [2, 2, 1, 0]
# [2, 3, 3, 0]
# final  995
# [1, 2, 2, 3]
# [1, 0, 1, 1]
# final  999
# [3, 0, 0, 1]
# [2, 3, 3, 2]
# final  999
# [1, 0, 0, 1]
# [2, 3, 3, 1]
# final  998
# [1, 3, 1, 2]
# final  994
# [3, 2, 0, 0]
# [1, 2, 2, 2]
# final  993
# [2, 1, 3, 2]
# [3, 0, 3, 1]
# final  992
# [2, 3, 1, 3]
# [1, 0, 1, 0]
# final  999
# [2, 3, 2, 3]
# [1, 3, 3, 2]
# final  999
# [3, 1, 0, 1]
# [2, 3, 0, 0]
# final  999
# [3, 0, 0, 1]
# [1, 1, 0, 1]
# final  992
# [3, 2, 3, 0]
# [3, 1, 1, 1]
# final  999
# [3, 3, 0, 2]
# final  996
# [3, 0, 3, 0]
# final  999
# [0, 1, 0, 1]
# [0, 3, 3, 1]
# final  996
# [2, 0, 2, 0]
# final  999
# [1, 2, 0, 2]
# final  999
# [0, 2, 0, 2]
# final  999
# [1, 3, 0, 1]
# final  990
# [2, 3, 2, 1]
# final  991
# [1, 1, 3, 1]
# final  998
# [0, 2, 2, 1]
# [1, 3, 0, 3]
# final  999
# [0, 0, 0, 0]
# final  998
# [1, 2, 3, 1]
# [1, 3, 3, 3]
# final  997
# [0, 0, 0, 2]
# final  996
# [0, 3, 1, 1]
# [1, 3, 3, 3]
# final  999
# [3, 3, 1, 2]
# [1, 3, 1, 2]
# final  989
# [3, 1, 0, 3]
# [2, 3, 0, 1]
# final  997
# [3, 1, 2, 0]
# [0, 2, 1, 2]
# [1, 3, 3, 0]
# final  988
# [2, 3, 0, 1]
# final  997
# [0, 1, 2, 2]
# [2, 0, 3, 1]
# final  998
# [1, 2, 3, 1]
# [3, 0, 3, 0]
# final  999
# [2, 3, 3, 2]
# final  975
# [0, 2, 3, 0]
# [2, 2, 3, 2]
# final  999
# [3, 2, 2, 3]
# [1, 3, 0, 2]
# final  999
# [3, 1, 1, 1]
# final  996
# [3, 0, 0, 2]
# [3, 3, 3, 3]
# final  997
# [3, 3, 3, 2]
# final  995
# [0, 2, 1, 0]
# [2, 1, 2, 1]
# final  997
# [2, 2, 0, 3]
# [2, 0, 1, 1]
# final  999
# [2, 0, 0, 0]
# final  998
# [3, 1, 1, 1]
# final  998
# [1, 2, 2, 0]
# [3, 1, 3, 1]
# final  997
# [0, 0, 3, 1]
# final  999
# [0, 2, 2, 0]
# [2, 1, 2, 1]
# final  988
# [0, 2, 3, 3]
# [3, 1, 1, 1]
# final  998
# [1, 3, 0, 3]
# final  997
# [2, 2, 0, 1]
# [0, 0, 3, 1]
# final  998
# [3, 3, 3, 0]
# [2, 0, 2, 0]
# final  996
# [1, 0, 0, 1]
# [1, 3, 1, 3]
# final  999
# [3, 1, 3, 1]
# final  987
# [0, 3, 0, 1]
# final  999
# [1, 2, 2, 1]
# [2, 0, 3, 3]
# final  997
# [3, 0, 1, 3]
# [2, 3, 0, 1]
# final  998
# [0, 1, 1, 1]
# [1, 0, 3, 3]
# final  997
# [3, 0, 0, 3]
# [3, 3, 1, 0]
# [2, 0, 2, 1]
# final  998
# [2, 1, 0, 2]
# [3, 0, 3, 3]
# final  999
# [0, 1, 3, 2]
# [1, 2, 3, 0]
# [0, 2, 2, 2]
# final  996
# [3, 3, 3, 1]
# final  998
# [3, 3, 2, 0]
# [1, 0, 0, 0]
# final  998
# [2, 2, 1, 2]
# [1, 1, 3, 1]
# final  993
# [0, 3, 2, 0]
# [2, 3, 0, 0]
# final  992
# [3, 2, 1, 1]
# [1, 2, 2, 2]
# final  999
# [1, 0, 1, 3]
# [3, 1, 1, 1]
# final  999
# [3, 1, 0, 3]
# [2, 3, 3, 2]
# final  996
# [1, 0, 3, 2]
# final  989
# [0, 3, 0, 0]
# final  994
# [2, 1, 2, 2]
# [2, 1, 0, 1]
# final  998
# [0, 1, 0, 2]
# [1, 2, 1, 2]
# final  994
# [1, 2, 2, 1]
# [2, 0, 3, 0]
# final  996
# [1, 0, 1, 0]
# final  999
# [3, 1, 1, 1]
# final  999
# [2, 2, 3, 2]
# final  998
# [3, 2, 1, 2]
# [2, 2, 3, 0]
# final  997
# [3, 1, 3, 2]
# [2, 2, 2, 1]
# final  986
# [3, 3, 1, 2]
# [2, 3, 0, 1]
# final  998
# [1, 0, 0, 2]
# final  996
# [2, 3, 0, 2]
# final  999
# [0, 2, 0, 2]
# final  997
# [0, 3, 0, 3]
# final  999
# [1, 2, 1, 0]
# final  997
# [0, 1, 1, 1]
# [1, 0, 1, 1]
# final  999
# [2, 0, 2, 3]
# [2, 3, 3, 1]
# final  999
# [0, 3, 3, 2]
# final  999
# [2, 0, 2, 2]
# [1, 0, 1, 0]
# final  997
# [3, 2, 3, 3]
# [2, 0, 1, 1]
# final  998
# [3, 2, 2, 0]
# [2, 0, 3, 1]
# final  997
# [0, 2, 1, 0]
# [3, 0, 3, 3]
# final  992
# [3, 0, 3, 2]
# final  999
# [0, 2, 2, 0]
# [0, 3, 0, 1]
# final  993
# [0, 2, 1, 0]
# [1, 0, 1, 2]
# final  969
# [1, 0, 3, 2]
# final  999
# [1, 1, 0, 3]
# [0, 0, 3, 0]
# final  996
# [0, 2, 0, 1]
# [1, 1, 0, 0]
# final  999
# [0, 3, 1, 1]
# [0, 3, 0, 1]
# final  999
# Hill Climbing       : 48/100
# Random Restart      : 100/100
# Simulated Annealing : 57/100

# %% [markdown]
# ## Preguntas de discusión
#
# 1. ¿Por qué Hill Climbing puede fallar aunque exista una solución?
#
#     R: Puede fallar si se queda atrapado en una meseta o un mínimo local. Aunque exista una mejor solución, como Hill Climbing se compara solo con sus vecinos evaluando que estén MEJOR que él, si la solución óptima está en otro punto de la función, se puede quedar atrapado en un mínimo local sin tener conocimiento de esto y pensar que es la mejor solución.
#
# 2. ¿Qué diferencia existe entre una meseta y un mínimo local?
#
#     R: En un mínimo local los vecinos tienen peor costo que el estado actual, mientras que en una meseta los vecinos tienen el mismo costo que el estado actual.
#
# 3. ¿Por qué Random Restart mejora la probabilidad de encontrar una solución?
#
#     R: Porque Random Restart cambia el punto de partida de Hill Climbing, y esto es justamente una solución al problema de quedarse atascado en mínimos locales o mesetas. De esta manera, con cada reinicio puede caer en diferentes regiones y encontrar nuevas soluciones para al final esocger la mejor.
#
# 4. ¿Qué ocurre en Simulated Annealing cuando la temperatura es muy alta?
#
#     R: Si la temperatura es muy alta, la probabilidad de aceptar *P(aceptar)* el valor candidato cuando el valor no es aceptado directamente por las condiciones de optimización, es alta. Con esto, se comportará como una búsqueda aleatoria. Si no se tiene un cooling rate apropiado con base en el contexto del problema y su distribución, puede llegar a alargar el intervalo de búsqueda, aunque esto también dependerá del límite de iteraciones para obtener estados de forma estocástica.
#
# 5. ¿Qué ocurre si la temperatura disminuye demasiado rápido?
#
#     R: Si la temperatura disminuye muy rápido, no se podrá realizar una búsqueda exploratoria exhaustiva, puesto que las condiciones de aceptación de valores no óptimos serán cada vez más estrictas. Esto, a su vez, hará que la fase de explotación se realice con una región de espacio reducida, recayendo en posibles minimos locales o mesetas.
#
# 6. ¿Cómo cambiaría el tamaño del espacio de búsqueda para 8 reinas?
#
#     R: Asumiendo que se mantiene la restricción de una sola reina por columna, se tiene que |X| = 8^8 = 16777216
#
# 7. ¿Cuál de los tres algoritmos fue más confiable en los experimentos?
#
#     R: Se observa que el mas confiable fue **Random Restart Hill Climbing*. Entre distintas ejecuciones del algoritmo, se le puede considerar como el más consistente entre la cantidad de iteraciones y los costos que este puede obtener.

# %% [markdown]
# ## Reto adicional
#
# Modifique:
#
# ```python
# N = 8
# ```
#
# y evalúe los algoritmos en el problema de las **8 reinas**.
#
# Compare:
#
# - tasa de éxito
#
# Hill Climbing       : 15/100
#
# Random Restart      : 96/100
#
# Simulated Annealing : 1/100
#
# Se puede observar que Random Restart tiene la mayor consistencia en los resultados, después de realizar 100 diferentes ejecuciones. Cabe recalcar que Simulated Annealing puede mejorar si se parametriza mejor según las necesidades.
#
# - número de iteraciones
#
# Hill Climbing       : 6
#
# Random Restart      : 5
#
# Simulated Annealing : 998
#
# - número de reinicios
#
# Random Restart tuvo 2 reinicios para el dataset probado
#
#
# - Simulated Annealing
#
# En general, entre más se subían la temperatura, iba encontrando mayores opciones de soluciones, pero se limitaba por la cantidad de steps, debido a la complejidad del espacio de movimientos.
#
# El cooling rate afecta la cantidad de iteraciones a realizar y los caminos que el algoritmo de Simulated Annealing toma, definiendo la tolerancia del estado de exploración.
